# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")

# %%
video_path = r"D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4"

# %%
results = model.predict(source=video_path, stream=True, save=True, show=False, conf=0.4)

for result in results:
    frame = result.plot()
# Out:
# video 1/1 (frame 1/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 88.9ms
# video 1/1 (frame 2/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 94.8ms
# video 1/1 (frame 3/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 1 backpack, 117.8ms
# video 1/1 (frame 4/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 1 backpack, 102.6ms
# video 1/1 (frame 5/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 1 backpack, 111.1ms
# video 1/1 (frame 6/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 1 backpack, 125.9ms
# video 1/1 (frame 7/943) D:\downloads\CV_tasks\Task_3\4236788-hd_1920_1080_25fps.mp4: 384x640 4 persons, 6 cars, 1 bus, 1 backpack, 102.9ms
# ...

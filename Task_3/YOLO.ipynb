# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# %%
model = YOLO("yolov8n.pt")

# %%
image_path = "D:\downloads\CV_tasks\Task_3\pexels-franco-monsalvo-252430633-29719238.jpg"  # Replace with the path to your image
image = cv2.imread(image_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\fares\AppData\Local\Temp\ipykernel_14076\3316310983.py:1: SyntaxWarning: invalid escape sequence '\d'
#   image_path = "D:\downloads\CV_tasks\Task_3\pexels-franco-monsalvo-252430633-29719238.jpg"  # Replace with the path to your image

# %%
results = model.predict(source=image_path, save=True, save_txt=True)  

result_image = results[0].plot()  

plt.imshow(cv2.cvtColor(result_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

cv2.imwrite("output.jpg", result_image)
# Out:
# image 1/1 D:\downloads\CV_tasks\Task_3\pexels-franco-monsalvo-252430633-29719238.jpg: 448x640 12 persons, 170.9ms
# Speed: 0.0ms preprocess, 170.9ms inference, 2.3ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\detect\predict5
# 1 label saved to runs\detect\predict5\labels
# True
